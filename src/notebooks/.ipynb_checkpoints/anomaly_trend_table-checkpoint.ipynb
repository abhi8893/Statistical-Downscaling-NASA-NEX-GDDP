# %%
import pandas as pd

# %%
df = pd.read_csv('/home/abhi/Documents/mygit/NEX-Analysis/pickles/Amravati/anomaly_trend/EnsMean_ALL21_anomaly_trend.csv')

# %%
df = df.drop('model', axis=1)

# %%
df.loc[:, 'variable': 'estimate'].pivot_table(index=['variable'], columns=['seas', 'scen', 'tslice'])
# Out:
#            estimate                                                     \
# seas         Annual                                                DJF
# scen     historical     rcp45               rcp85           historical
# tslice     baseline       far      near       far      near   baseline
# variable
# pr        -0.006052  0.006842  0.007546  0.007752  0.009229  -0.000068
# tas        0.017482  0.004709  0.030073  0.056406  0.042272   0.015269
# tasmax     0.015876  0.002181  0.029008  0.053835  0.038748   0.012906
# tasmin     0.019089  0.007236  0.031137  0.058976  0.045796   0.017633
#
#                                                   ...                       \
# seas                                              ...        MAM
# scen         rcp45               rcp85            ... historical     rcp45
# tslice         far      near       far      near  ...   baseline       far
# variable                                          ...
# ...
